# %% [markdown]
# ## Teste do carregamento e eficiencia do módulo fortran

# %%
from m3l.prepare_module import prepare

# %%
modulo = prepare.teste('h2o.xyz')

# %%
dicionario = {'output1': modulo[0], 'output2': modulo[1]}
dicionario
# Out:
# {'output1': 100.0, 'output2': 0.0}
