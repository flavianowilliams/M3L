# %% [markdown]
# # Teste da preparação do sistema físico

# %%
import sys
sys.path.insert(0, '../')
from m3l import structure as strc

# %%
# !ls
# Out:
#  C2H4.xyz	 h2.xyz		 teste_forcefield.ipynb   teste_sistema.ipynb
# 'H2O(liq).xyz'	 structure.log	 teste_fortran.ipynb

# %%
sistema = strc.System(0, 15, 15, 'H2O(liq).xyz')
print(sistema)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2719/3868985024.py in <cell line: 1>()
# ----> 1 sistema = strc.System(0, 15, 15, 'H2O(liq).xyz')
#       2 print(sistema)
#
# ~/Documentos/TestPYPI/M3L/M3L/src/tests/../m3l/structure.py in __init__(self, a, b, c, filename)
#      69         self.setXYZ(filename)
#      70         self.convertUnits()
# ---> 71         self.setCCP()
#      72         self.setVolume()
#      73
#
# ~/Documentos/TestPYPI/M3L/M3L/src/tests/../m3l/structure.py in setCCP(self)
#      94             logging.critical('Constant lattice must be larger than zero!')
#      95             logging.info('Job turned out')
# ---> 96             quit()
#      97
#      98     def convertUnits(self):
#
# NameError: name 'quit' is not defined

# %%
sistema.atoms[0:2]

# %%
new = sistema.setCCP()
sistema.atoms[0:2]

# %%
volume = sistema.getVolume()
print(volume['value'])
