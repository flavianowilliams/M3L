# %% [markdown]
# # Teste da preparação do sistema físico

# %%
from m3l import structure as strc
from m3l import symmetry as sym
from m3l import machine_learning as ml

# %%
# !ls
# Out:
#  C2H4.xyz	 h2.xyz		 teste_forcefield.ipynb   teste_sistema.ipynb
# 'H2O(liq).xyz'	 structure.log	 teste_fortran.ipynb

# %% [markdown]
# # carregando sistema físico (átomos, CCP, célula unitária)

# %%
sistema = strc.System(15, 15, 15, 'h2.xyz')
print(sistema)
# Out:
# Célula unitária ortorrômbica
#
# Volume: 3374.9999999999995 A³
#
# Total: 2 átomos

# %%
sistema.atoms[0:2]
# Out:
# [{'id': 0, 'atom': 'H', 'x': 0.0, 'y': 0.0, 'z': 0.0, 's2': 0.0},
#  {'id': 1,
#   'atom': 'H',
#   'x': 1.8897261246257702,
#   'y': 0.0,
#   'z': 0.0,
#   's2': 0.0}]

# %%
new = sistema.setCCP()
sistema.atoms
# Out:
# [{'id': 0, 'atom': 'H', 'x': 0.0, 'y': 0.0, 'z': 0.0, 's2': 0.0},
#  {'id': 1,
#   'atom': 'H',
#   'x': 1.8897261246257702,
#   'y': 0.0,
#   'z': 0.0,
#   's2': 0.0}]

# %%
volume = sistema.getVolume()
print(volume['value'])
# Out:
# 22775.628919276263

# %% [markdown]
# # aplicando condições de simetria

# %%
symmetry = sym.Symm2D(sistema.atoms, 1.0, 6.0)
symmetry.gFunction()
# Out:
# [{'id': 0,
#   'atom': 'H',
#   'x': 0.0,
#   'y': 0.0,
#   'z': 0.0,
#   's2': 3.5640013670101715e-08},
#  {'id': 1,
#   'atom': 'H',
#   'x': 1.8897261246257702,
#   'y': 0.0,
#   'z': 0.0,
#   's2': 0.0}]
