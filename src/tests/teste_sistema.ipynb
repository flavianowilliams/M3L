# %% [markdown]
# # Teste da preparação do sistema físico

# %%
from m3l import structure as strc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/flaviano/Documentos/GitHub/M3L/src/tests/teste_sistema.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/flaviano/Documentos/GitHub/M3L/src/tests/teste_sistema.ipynb#ch0000001?line=0'>1</a> from m3l import structure as strc
#
# ModuleNotFoundError: No module named 'm3l'

# %%
# !ls
# Out:
#  C2H4.xyz	 h2.xyz		 teste_forcefield.ipynb   teste_sistema.ipynb
# 'H2O(liq).xyz'	 structure.log	 teste_fortran.ipynb

# %%
sistema = strc.System(15, 15, 15, 'H2O(liq).xyz')
print(sistema)
# Out:
# Célula unitária ortorrômbica
#
# Volume: 3374.9999999999995 A³
#
# Total: 927 átomos

# %%
sistema.atoms[0:2]
# Out:
# [{'id': 0,
#   'atom': 'O',
#   'x': 4.646350880840741,
#   'y': 23.014367869731252,
#   'z': 23.250980477795643},
#  {'id': 1,
#   'atom': 'H',
#   'x': 4.799477278445291,
#   'y': 21.470102577948317,
#   'z': 22.336587359516223}]

# %%
new = sistema.setCCP()
sistema.atoms[0:2]
# Out:
# [{'id': 0,
#   'atom': 'O',
#   'x': 4.646350880840741,
#   'y': 23.014367869731252,
#   'z': 23.250980477795643},
#  {'id': 1,
#   'atom': 'H',
#   'x': 4.799477278445291,
#   'y': 21.470102577948317,
#   'z': 22.336587359516223}]

# %%
volume = sistema.getVolume()
print(volume['value'])
# Out:
# 22775.628919276263
