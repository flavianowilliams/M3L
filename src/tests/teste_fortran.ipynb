# %% [markdown]
# ## Teste do carregamento e eficiencia do módulo fortran

# %%
from m3l.prepare_module import prepare
# Out:
# Running cells with 'Python 3.10.4 ('venv': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/flaviano/Documentos/GitHub/M3L/venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !ls
# Out:
# C2H4.xyz  fort.1  h2.xyz  teste_fortran.ipynb  teste_sistema.ipynb

# %%
modulo = prepare.teste('h2.xyz')

# %%
dicionario = modulo[2]
dicionario
# Out:
# array([0., 0.])
